# %%
import folium as fl 
poa = [-30.0346, -51.2177] 
sp = [-23.5505, -46.6333] 
rj = [-22.9068, -43.1729] 
cr = [-25.4290, -49.2671] 
bh = [-19.9173, -43.9345] 

mapa = fl.Map(location=[sp[0],sp[1]], zoom_start=5) 

fl.Marker([poa[0], poa[1]], popup='Porto Alegre, RS, Brasil').add_to(mapa) 
fl.Marker([sp[0], sp[1]], popup='São Paulo, SP, Brasil').add_to(mapa) 
fl.Marker([rj[0], rj[1]], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa) 
fl.Marker([cr[0], cr[1]], popup='Curitiba, PR, Brasil').add_to(mapa) 
fl.Marker([bh[0], bh[1]], popup='Belo Horizonte, MG, Brasil').add_to(mapa) 

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2e29891f3402590d54ffa6c8f088a2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2e29891f3402590d54ffa6c8f088a2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2e29891f3402590d54ffa6c8f088a2b = L.map(
#                 &quot;map_c2e29891f3402590d54ffa6c8f088a2b&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21a50b17d9ffb873c0d4b837517a0cbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_21a50b17d9ffb873c0d4b837517a0cbf.addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#             var marker_d96bb213347ccc47794e03476d4dbdf5 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#         var popup_7f77e38a6772e2c945682e2af688e8af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b215f65dbdf2bf04ac088dba50ec0072 = $(`&lt;div id=&quot;html_b215f65dbdf2bf04ac088dba50ec0072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_7f77e38a6772e2c945682e2af688e8af.setContent(html_b215f65dbdf2bf04ac088dba50ec0072);
#
#
#
#         marker_d96bb213347ccc47794e03476d4dbdf5.bindPopup(popup_7f77e38a6772e2c945682e2af688e8af)
#         ;
#
#
#
#
#             var marker_0a6ae1263af41d7d6a4a3cc98a553629 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#         var popup_796eae04baf94b32b8bbbd1a5b295afd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30fa98e2eb1ae9c224be34ab3bd80b4a = $(`&lt;div id=&quot;html_30fa98e2eb1ae9c224be34ab3bd80b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_796eae04baf94b32b8bbbd1a5b295afd.setContent(html_30fa98e2eb1ae9c224be34ab3bd80b4a);
#
#
#
#         marker_0a6ae1263af41d7d6a4a3cc98a553629.bindPopup(popup_796eae04baf94b32b8bbbd1a5b295afd)
#         ;
#
#
#
#
#             var marker_c864124cebfec991953d644caa4eff39 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#         var popup_cadcc526c2832fac4f2dce3f5c512d1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a69a47d79b4374b2cc36fe58d5cc041 = $(`&lt;div id=&quot;html_0a69a47d79b4374b2cc36fe58d5cc041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_cadcc526c2832fac4f2dce3f5c512d1f.setContent(html_0a69a47d79b4374b2cc36fe58d5cc041);
#
#
#
#         marker_c864124cebfec991953d644caa4eff39.bindPopup(popup_cadcc526c2832fac4f2dce3f5c512d1f)
#         ;
#
#
#
#
#             var marker_7b459d2efa8a3212fbecf0a8c6197fd4 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#         var popup_54fa5b885400aeb9a602d91698f3d6c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_603174deac33887082c8da45bee1e78f = $(`&lt;div id=&quot;html_603174deac33887082c8da45bee1e78f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_54fa5b885400aeb9a602d91698f3d6c8.setContent(html_603174deac33887082c8da45bee1e78f);
#
#
#
#         marker_7b459d2efa8a3212fbecf0a8c6197fd4.bindPopup(popup_54fa5b885400aeb9a602d91698f3d6c8)
#         ;
#
#
#
#
#             var marker_3ca917add27dc8d1d8b78ec6a468cc2a = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_c2e29891f3402590d54ffa6c8f088a2b);
#
#
#         var popup_e2af41fbd99fe742f3e6883dbf02d646 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f33c778032835c1aace155a1d71425bf = $(`&lt;div id=&quot;html_f33c778032835c1aace155a1d71425bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_e2af41fbd99fe742f3e6883dbf02d646.setContent(html_f33c778032835c1aace155a1d71425bf);
#
#
#
#         marker_3ca917add27dc8d1d8b78ec6a468cc2a.bindPopup(popup_e2af41fbd99fe742f3e6883dbf02d646)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
